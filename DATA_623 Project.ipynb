# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import regex as re
import seaborn as sns

# %%
data_HGJ = pd.read_excel('Raw_Data.xlsx', sheet_name='HGJ')
data_HGJ['Hospital'] ='Jewish General'
display(data_HGJ.columns)
display(data_HGJ.dtypes)
display(data_HGJ.shape)
display(data_HGJ)
# Out:
# Index(['Patient #', 'Sex', 'Age', 'Primary Site', 'T-stage', 'N-stage',
#        'M-stage', 'TNM group stage', 'HPV status',
#        'Time – diagnosis to diagnosis (days)',
#        'Time – diagnosis to PET (days)', 'Time – diagnosis to CT sim (days)',
#        'Time – diagnosis to start treatment (days)',
#        'Time – diagnosis to end treatment (days)', 'Therapy', 'Surgery',
#        'Time – diagnosis to last follow-up(days)', 'Locoregional', 'Distant',
#        'Death', 'Time – diagnosis to LR (days)',
#        'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)',
#        'Hospital'],
#       dtype='object')
# Patient #                                      object
# Sex                                            object
# Age                                             int64
# Primary Site                                   object
# T-stage                                        object
# N-stage                                        object
# M-stage                                        object
# TNM group stage                                object
# HPV status                                     object
# Time – diagnosis to diagnosis (days)            int64
# Time – diagnosis to PET (days)                  int64
# Time – diagnosis to CT sim (days)               int64
# Time – diagnosis to start treatment (days)      int64
# Time – diagnosis to end treatment (days)        int64
# Therapy                                        object
# Surgery                                         int64
# Time – diagnosis to last follow-up(days)        int64
# Locoregional                                    int64
# Distant                                         int64
# Death                                           int64
# Time – diagnosis to LR (days)                 float64
# Time – diagnosis to DM (days)                 float64
# Time – diagnosis to Death (days)              float64
# Hospital                                       object
# dtype: object
# (91, 24)
#      Patient # Sex  Age Primary Site T-stage N-stage M-stage TNM group stage  \
# 0   HN-HGJ-001   M   79       Larynx      T3      N0      M0       stage III
# 1   HN-HGJ-002   M   41  Nasopharynx      T1      N1      M0       stage IIB
# 2   HN-HGJ-003   M   75       Larynx      T3     N2b      M0       stage IVA
# 3   HN-HGJ-004   M   53  Nasopharynx      T3      N1      M0       stage III
# 4   HN-HGJ-005   M   74  Nasopharynx      T1      N1      M0       stage IIB
# ..         ...  ..  ...          ...     ...     ...     ...             ...
# 86  HN-HGJ-088   M   59   Oropharynx      T2      N0      M0        stage II
# 87  HN-HGJ-089   M   66   Oropharynx      T1     N2c      M0       stage IVA
# 88  HN-HGJ-090   M   53   Oropharynx      T2     N2a      M0       stage IVA
# 89  HN-HGJ-091   M   65   Oropharynx      T3      N0      M0       stage III
# 90  HN-HGJ-092   M   53   Oropharynx      T2      N1      M0       stage III
#
#    HPV status  Time – diagnosis to diagnosis (days)  ...          Therapy  \
# 0           -                                     0  ...  chemo radiation
# 1           -                                     0  ...  chemo radiation
# 2         NaN                                     0  ...  chemo radiation
# 3         NaN                                     0  ...        radiation
# 4           -                                     0  ...  chemo radiation
# ..        ...                                   ...  ...              ...
# 86          +                                     0  ...  chemo radiation
# 87          +                                     0  ...  chemo radiation
# 88          +                                     0  ...  chemo radiation
# 89          +                                     0  ...  chemo radiation
# 90          +                                     0  ...  chemo radiation
#
#     Surgery  Time – diagnosis to last follow-up(days)  Locoregional Distant  \
# 0         0                                      2123             1       0
# 1         0                                      2114             1       0
# 2         0                                      1098             1       1
# 3         0                                      2974             0       0
# 4         0                                      2509             0       0
# ..      ...                                       ...           ...     ...
# 86        0                                       858             0       0
# 87        0                                       444             0       1
# 88        1                                       817             0       0
# 89        0                                       719             0       0
# 90        1                                       824             0       0
#
#     Death  Time – diagnosis to LR (days)  Time – diagnosis to DM (days)  \
# 0       0                          692.0                            NaN
# 1       0                          918.0                            NaN
# 2       1                          441.0                          441.0
# 3       0                            NaN                            NaN
# 4       1                            NaN                            NaN
# ..    ...                            ...                            ...
# 86      0                            NaN                            NaN
# 87      0                            NaN                          329.0
# 88      0                            NaN                            NaN
# 89      0                            NaN                            NaN
# 90      0                            NaN                            NaN
#
#     Time – diagnosis to Death (days)        Hospital
# 0                                NaN  Jewish General
# 1                                NaN  Jewish General
# 2                             1098.0  Jewish General
# 3                                NaN  Jewish General
# 4                             2509.0  Jewish General
# ..                               ...             ...
# 86                               NaN  Jewish General
# 87                               NaN  Jewish General
# 88                               NaN  Jewish General
# 89                               NaN  Jewish General
# 90                               NaN  Jewish General
#
# [91 rows x 24 columns]

# %%
data_CHUS = pd.read_excel('Raw_Data.xlsx', sheet_name='CHUS')
data_CHUS['Hospital'] ='Univ of Sherbrooke'
display(data_CHUS.columns)
display(data_CHUS.dtypes)
display(data_CHUS.shape)
# Out:
# Index(['Patient #', 'Sex', 'Age', 'Primary Site', 'T-stage', 'N-stage',
#        'M-stage', 'TNM group stage', 'HPV status',
#        'Time – diagnosis to diagnosis (days)',
#        'Time – diagnosis to PET (days)', 'Time – diagnosis to CT sim (days)',
#        'Time – diagnosis to start treatment (days)',
#        'Time – diagnosis to end treatment (days)', 'Therapy', 'Surgery',
#        'Time – diagnosis to last follow-up (days)', 'Locoregional', 'Distant',
#        'Death', 'Time – diagnosis to LR (days)',
#        'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)',
#        'Hospital'],
#       dtype='object')
# Patient #                                      object
# Sex                                            object
# Age                                             int64
# Primary Site                                   object
# T-stage                                        object
# N-stage                                        object
# M-stage                                        object
# TNM group stage                                object
# HPV status                                     object
# Time – diagnosis to diagnosis (days)            int64
# Time – diagnosis to PET (days)                  int64
# Time – diagnosis to CT sim (days)              object
# Time – diagnosis to start treatment (days)      int64
# Time – diagnosis to end treatment (days)        int64
# Therapy                                        object
# Surgery                                       float64
# Time – diagnosis to last follow-up (days)       int64
# Locoregional                                    int64
# Distant                                         int64
# Death                                           int64
# Time – diagnosis to LR (days)                 float64
# Time – diagnosis to DM (days)                 float64
# Time – diagnosis to Death (days)              float64
# Hospital                                       object
# dtype: object
# (101, 24)

# %%
data_HMR = pd.read_excel('Raw_Data.xlsx', sheet_name='HMR')
data_HMR['Hospital'] ='Maisonneuve-Rosemont'
display(data_HMR.columns)
display(data_HMR.dtypes)
display(data_HMR.shape)
# Out:
# Index(['Patient #', 'Sex', 'Age', 'Primary Site', 'T-stage', 'N-stage',
#        'M-stage', 'TNM group stage', 'HPV status',
#        'Time – diagnosis to diagnosis (days)',
#        'Time – diagnosis to PET (days)', 'Time – diagnosis to CT sim (days)',
#        'Time – diagnosis to start treatment (days)',
#        'Time – diagnosis to end treatment (days)', 'Therapy', 'Surgery',
#        'Time – diagnosis to last follow-up(days)', 'Locoregional', 'Distant',
#        'Death', 'Time – diagnosis to LR (days)',
#        'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)',
#        'Hospital'],
#       dtype='object')
# Patient #                                      object
# Sex                                            object
# Age                                             int64
# Primary Site                                   object
# T-stage                                        object
# N-stage                                        object
# M-stage                                        object
# TNM group stage                                object
# HPV status                                     object
# Time – diagnosis to diagnosis (days)            int64
# Time – diagnosis to PET (days)                  int64
# Time – diagnosis to CT sim (days)               int64
# Time – diagnosis to start treatment (days)      int64
# Time – diagnosis to end treatment (days)        int64
# Therapy                                        object
# Surgery                                       float64
# Time – diagnosis to last follow-up(days)        int64
# Locoregional                                    int64
# Distant                                         int64
# Death                                           int64
# Time – diagnosis to LR (days)                 float64
# Time – diagnosis to DM (days)                 float64
# Time – diagnosis to Death (days)              float64
# Hospital                                       object
# dtype: object
# (41, 24)

# %%
data_CHUM = pd.read_excel('Raw_Data.xlsx', sheet_name='CHUM')
data_CHUM['Hospital'] ='Montreal Univ'
display(data_CHUM.columns)
display(data_CHUM.dtypes)
display(data_CHUM.shape)
# Out:
# Index(['Patient #', 'Sex', 'Age', 'Primary Site', 'T-stage', 'N-stage',
#        'M-stage', 'TNM group stage', 'HPV status',
#        'Time – diagnosis to diagnosis (days)',
#        'Time – diagnosis to PET (days)', 'Time – diagnosis to CT sim (days)',
#        'Time – diagnosis to start treatment (days)',
#        'Time – diagnosis to end treatment (days)', 'Therapy', 'Surgery',
#        'Time – diagnosis to last follow-up(days)', 'Locoregional', 'Distant',
#        'Death', 'Time – diagnosis to LR (days)',
#        'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)',
#        'Hospital'],
#       dtype='object')
# Patient #                                      object
# Sex                                            object
# Age                                           float64
# Primary Site                                   object
# T-stage                                        object
# N-stage                                        object
# M-stage                                        object
# TNM group stage                                object
# HPV status                                     object
# Time – diagnosis to diagnosis (days)            int64
# Time – diagnosis to PET (days)                  int64
# Time – diagnosis to CT sim (days)              object
# Time – diagnosis to start treatment (days)      int64
# Time – diagnosis to end treatment (days)        int64
# Therapy                                        object
# Surgery                                       float64
# Time – diagnosis to last follow-up(days)        int64
# Locoregional                                    int64
# Distant                                         int64
# Death                                           int64
# Time – diagnosis to LR (days)                 float64
# Time – diagnosis to DM (days)                 float64
# Time – diagnosis to Death (days)              float64
# Hospital                                       object
# dtype: object
# (65, 24)

# %%
data_raw = pd.concat([data_HGJ, data_CHUS, data_HMR, data_CHUM], ignore_index=True)
display(data_raw.columns)
display(data_raw.dtypes)
display(data_raw.shape)
# Out:
# Index(['Patient #', 'Sex', 'Age', 'Primary Site', 'T-stage', 'N-stage',
#        'M-stage', 'TNM group stage', 'HPV status',
#        'Time – diagnosis to diagnosis (days)',
#        'Time – diagnosis to PET (days)', 'Time – diagnosis to CT sim (days)',
#        'Time – diagnosis to start treatment (days)',
#        'Time – diagnosis to end treatment (days)', 'Therapy', 'Surgery',
#        'Time – diagnosis to last follow-up(days)', 'Locoregional', 'Distant',
#        'Death', 'Time – diagnosis to LR (days)',
#        'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)',
#        'Hospital', 'Time – diagnosis to last follow-up (days)'],
#       dtype='object')
# Patient #                                      object
# Sex                                            object
# Age                                           float64
# Primary Site                                   object
# T-stage                                        object
# N-stage                                        object
# M-stage                                        object
# TNM group stage                                object
# HPV status                                     object
# Time – diagnosis to diagnosis (days)            int64
# Time – diagnosis to PET (days)                  int64
# Time – diagnosis to CT sim (days)              object
# Time – diagnosis to start treatment (days)      int64
# Time – diagnosis to end treatment (days)        int64
# Therapy                                        object
# Surgery                                       float64
# Time – diagnosis to last follow-up(days)      float64
# Locoregional                                    int64
# Distant                                         int64
# Death                                           int64
# Time – diagnosis to LR (days)                 float64
# Time – diagnosis to DM (days)                 float64
# Time – diagnosis to Death (days)              float64
# Hospital                                       object
# Time – diagnosis to last follow-up (days)     float64
# dtype: object
# (298, 25)

# %%
data_raw['Time – diagnosis to diagnosis (days)'].sum()
# Out:
# 0

# %%
data_raw
# Out:
#        Patient # Sex        Age Primary Site T-stage N-stage M-stage  \
# 0     HN-HGJ-001   M  79.000000       Larynx      T3      N0      M0
# 1     HN-HGJ-002   M  41.000000  Nasopharynx      T1      N1      M0
# 2     HN-HGJ-003   M  75.000000       Larynx      T3     N2b      M0
# 3     HN-HGJ-004   M  53.000000  Nasopharynx      T3      N1      M0
# 4     HN-HGJ-005   M  74.000000  Nasopharynx      T1      N1      M0
# ..           ...  ..        ...          ...     ...     ...     ...
# 293  HN-CHUM-061   M  72.000000   Oropharynx      T2      N2      M0
# 294  HN-CHUM-062   M  72.000000   Oropharynx      T3      N1      M0
# 295  HN-CHUM-063   M  77.213699   Oropharynx      T3      N2      M0
# 296  HN-CHUM-064   M  73.000000   Oropharynx      T3      N3      M0
# 297  HN-CHUM-065   M  81.000000   Oropharynx      T3      N0      M0
#
#     TNM group stage HPV status  Time – diagnosis to diagnosis (days)  ...  \
# 0         stage III          -                                     0  ...
# 1         stage IIB          -                                     0  ...
# 2         stage IVA        NaN                                     0  ...
# 3         stage III        NaN                                     0  ...
# 4         stage IIB          -                                     0  ...
# ..              ...        ...                                   ...  ...
# 293        Stage IV        NaN                                     0  ...
# 294       Stage III        NaN                                     0  ...
# 295        Stage IV        NaN                                     0  ...
# 296        Stage IV        NaN                                     0  ...
# 297        Stage IV        NaN                                     0  ...
#
#      Surgery Time – diagnosis to last follow-up(days)  Locoregional  Distant  \
# 0        0.0                                   2123.0             1        0
# 1        0.0                                   2114.0             1        0
# 2        0.0                                   1098.0             1        1
# 3        0.0                                   2974.0             0        0
# 4        0.0                                   2509.0             0        0
# ..       ...                                      ...           ...      ...
# 293      NaN                                    464.0             1        0
# 294      NaN                                   1379.0             0        0
# 295      NaN                                   2012.0             1        1
# 296      NaN                                    870.0             0        0
# 297      NaN                                    788.0             0        0
#
#     Death  Time – diagnosis to LR (days)  Time – diagnosis to DM (days)  \
# 0       0                          692.0                            NaN
# 1       0                          918.0                            NaN
# 2       1                          441.0                          441.0
# 3       0                            NaN                            NaN
# 4       1                            NaN                            NaN
# ..    ...                            ...                            ...
# 293     1                          428.0                            NaN
# 294     0                            NaN                            NaN
# 295     0                          832.0                          832.0
# 296     0                            NaN                            NaN
# 297     0                            NaN                            NaN
#
#      Time – diagnosis to Death (days)        Hospital  \
# 0                                 NaN  Jewish General
# 1                                 NaN  Jewish General
# 2                              1098.0  Jewish General
# 3                                 NaN  Jewish General
# 4                              2509.0  Jewish General
# ..                                ...             ...
# 293                             464.0   Montreal Univ
# 294                               NaN   Montreal Univ
# 295                               NaN   Montreal Univ
# 296                               NaN   Montreal Univ
# 297                               NaN   Montreal Univ
#
#      Time – diagnosis to last follow-up (days)
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 293                                        NaN
# 294                                        NaN
# 295                                        NaN
# 296                                        NaN
# 297                                        NaN
#
# [298 rows x 25 columns]

# %%
data_raw.columns
# Out:
# Index(['Patient #', 'Sex', 'Age', 'Primary Site', 'T-stage', 'N-stage',
#        'M-stage', 'TNM group stage', 'HPV status',
#        'Time – diagnosis to diagnosis (days)',
#        'Time – diagnosis to PET (days)', 'Time – diagnosis to CT sim (days)',
#        'Time – diagnosis to start treatment (days)',
#        'Time – diagnosis to end treatment (days)', 'Therapy', 'Surgery',
#        'Time – diagnosis to last follow-up(days)', 'Locoregional', 'Distant',
#        'Death', 'Time – diagnosis to LR (days)',
#        'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)',
#        'Hospital', 'Time – diagnosis to last follow-up (days)'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data_raw.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
plt.savefig("visualizing_missing_data_with_heatmap_Seaborn_Python.png", dpi=100)

# %%
col = list(data_raw.columns)
col
# Out:
# ['Patient #',
#  'Sex',
#  'Age',
#  'Primary Site',
#  'T-stage',
#  'N-stage',
#  'M-stage',
#  'TNM group stage',
#  'HPV status',
#  'Time – diagnosis to diagnosis (days)',
#  'Time – diagnosis to PET (days)',
#  'Time – diagnosis to CT sim (days)',
#  'Time – diagnosis to start treatment (days)',
#  'Time – diagnosis to end treatment (days)',
#  'Therapy',
#  'Surgery',
#  'Time – diagnosis to last follow-up(days)',
#  'Locoregional',
#  'Distant',
#  'Death',
#  'Time – diagnosis to LR (days)',
#  'Time – diagnosis to DM (days)',
#  'Time – diagnosis to Death (days)',
#  'Hospital',
#  'Time – diagnosis to last follow-up (days)']

# %%
for el in col:
    display(data_raw[el].unique())
# Out:
# array(['HN-HGJ-001', 'HN-HGJ-002', 'HN-HGJ-003', 'HN-HGJ-004',
#        'HN-HGJ-005', 'HN-HGJ-006', 'HN-HGJ-007', 'HN-HGJ-008',
#        'HN-HGJ-009', 'HN-HGJ-010', 'HN-HGJ-011', 'HN-HGJ-012',
#        'HN-HGJ-013', 'HN-HGJ-014', 'HN-HGJ-015', 'HN-HGJ-016',
#        'HN-HGJ-017', 'HN-HGJ-018', 'HN-HGJ-019', 'HN-HGJ-020',
#        'HN-HGJ-021', 'HN-HGJ-022', 'HN-HGJ-023', 'HN-HGJ-024',
#        'HN-HGJ-025', 'HN-HGJ-026', 'HN-HGJ-027', 'HN-HGJ-028',
#        'HN-HGJ-029', 'HN-HGJ-030', 'HN-HGJ-031', 'HN-HGJ-032',
#        'HN-HGJ-033', 'HN-HGJ-034', 'HN-HGJ-035', 'HN-HGJ-036',
#        'HN-HGJ-037', 'HN-HGJ-038', 'HN-HGJ-039', 'HN-HGJ-040',
#        'HN-HGJ-041', 'HN-HGJ-042', 'HN-HGJ-043', 'HN-HGJ-044',
#        'HN-HGJ-045', 'HN-HGJ-046', 'HN-HGJ-047', 'HN-HGJ-048',
#        'HN-HGJ-049', 'HN-HGJ-050', 'HN-HGJ-051', 'HN-HGJ-052',
#        'HN-HGJ-053', 'HN-HGJ-054', 'HN-HGJ-055', 'HN-HGJ-056',
#        'HN-HGJ-057', 'HN-HGJ-058', 'HN-HGJ-059', 'HN-HGJ-060',
#        'HN-HGJ-061', 'HN-HGJ-062', 'HN-HGJ-063', 'HN-HGJ-064',
#        'HN-HGJ-065', 'HN-HGJ-066', 'HN-HGJ-067', 'HN-HGJ-069',
#        'HN-HGJ-070', 'HN-HGJ-071', 'HN-HGJ-072', 'HN-HGJ-073',
#        'HN-HGJ-074', 'HN-HGJ-075', 'HN-HGJ-076', 'HN-HGJ-077',
#        'HN-HGJ-078', 'HN-HGJ-079', 'HN-HGJ-080', 'HN-HGJ-081',
#        'HN-HGJ-082', 'HN-HGJ-083', 'HN-HGJ-084', 'HN-HGJ-085',
#        'HN-HGJ-086', 'HN-HGJ-087', 'HN-HGJ-088', 'HN-HGJ-089',
#        'HN-HGJ-090', 'HN-HGJ-091', 'HN-HGJ-092', 'HN-CHUS-001',
#        'HN-CHUS-002', 'HN-CHUS-003', 'HN-CHUS-004', 'HN-CHUS-005',
#        'HN-CHUS-006', 'HN-CHUS-007', 'HN-CHUS-008', 'HN-CHUS-009',
#        'HN-CHUS-010', 'HN-CHUS-011', 'HN-CHUS-012', 'HN-CHUS-013',
#        'HN-CHUS-014', 'HN-CHUS-015', 'HN-CHUS-016', 'HN-CHUS-017',
#        'HN-CHUS-018', 'HN-CHUS-019', 'HN-CHUS-020', 'HN-CHUS-021',
#        'HN-CHUS-022', 'HN-CHUS-023', 'HN-CHUS-024', 'HN-CHUS-025',
#        'HN-CHUS-026', 'HN-CHUS-027', 'HN-CHUS-028', 'HN-CHUS-029',
#        'HN-CHUS-030', 'HN-CHUS-031', 'HN-CHUS-032', 'HN-CHUS-033',
#        'HN-CHUS-034', 'HN-CHUS-035', 'HN-CHUS-036', 'HN-CHUS-037',
#        'HN-CHUS-038', 'HN-CHUS-039', 'HN-CHUS-040', 'HN-CHUS-041',
#        'HN-CHUS-042', 'HN-CHUS-043', 'HN-CHUS-044', 'HN-CHUS-045',
#        'HN-CHUS-046', 'HN-CHUS-047', 'HN-CHUS-048', 'HN-CHUS-049',
#        'HN-CHUS-050', 'HN-CHUS-051', 'HN-CHUS-052', 'HN-CHUS-053',
#        'HN-CHUS-054', 'HN-CHUS-055', 'HN-CHUS-056', 'HN-CHUS-057',
#        'HN-CHUS-058', 'HN-CHUS-059', 'HN-CHUS-060', 'HN-CHUS-061',
#        'HN-CHUS-062', 'HN-CHUS-063', 'HN-CHUS-064', 'HN-CHUS-065',
#        'HN-CHUS-066', 'HN-CHUS-067', 'HN-CHUS-068', 'HN-CHUS-069',
#        'HN-CHUS-070', 'HN-CHUS-071', 'HN-CHUS-072', 'HN-CHUS-073',
#        'HN-CHUS-074', 'HN-CHUS-075', 'HN-CHUS-076', 'HN-CHUS-077',
#        'HN-CHUS-078', 'HN-CHUS-080', 'HN-CHUS-081', 'HN-CHUS-082',
#        'HN-CHUS-083', 'HN-CHUS-084', 'HN-CHUS-085', 'HN-CHUS-086',
#        'HN-CHUS-087', 'HN-CHUS-088', 'HN-CHUS-089', 'HN-CHUS-090',
#        'HN-CHUS-091', 'HN-CHUS-092', 'HN-CHUS-093', 'HN-CHUS-094',
#        'HN-CHUS-095', 'HN-CHUS-096', 'HN-CHUS-097', 'HN-CHUS-098',
#        'HN-CHUS-099', 'HN-CHUS-100', 'HN-CHUS-101', 'HN-CHUS-102',
#        'HN-HMR-001', 'HN-HMR-002', 'HN-HMR-003', 'HN-HMR-004',
#        'HN-HMR-005', 'HN-HMR-006', 'HN-HMR-007', 'HN-HMR-008',
#        'HN-HMR-009', 'HN-HMR-010', 'HN-HMR-011', 'HN-HMR-012',
#        'HN-HMR-013', 'HN-HMR-014', 'HN-HMR-015', 'HN-HMR-016',
#        'HN-HMR-017', 'HN-HMR-018', 'HN-HMR-019', 'HN-HMR-020',
#        'HN-HMR-021', 'HN-HMR-022', 'HN-HMR-023', 'HN-HMR-024',
#        'HN-HMR-025', 'HN-HMR-026', 'HN-HMR-027', 'HN-HMR-028',
#        'HN-HMR-029', 'HN-HMR-030', 'HN-HMR-031', 'HN-HMR-032',
#        'HN-HMR-033', 'HN-HMR-034', 'HN-HMR-035', 'HN-HMR-036',
#        'HN-HMR-037', 'HN-HMR-038', 'HN-HMR-039', 'HN-HMR-040',
#        'HN-HMR-041', 'HN-CHUM-001', 'HN-CHUM-002', 'HN-CHUM-003',
#        'HN-CHUM-004', 'HN-CHUM-005', 'HN-CHUM-006', 'HN-CHUM-007',
#        'HN-CHUM-008', 'HN-CHUM-009', 'HN-CHUM-010', 'HN-CHUM-011',
#        'HN-CHUM-012', 'HN-CHUM-013', 'HN-CHUM-014', 'HN-CHUM-015',
#        'HN-CHUM-016', 'HN-CHUM-017', 'HN-CHUM-018', 'HN-CHUM-019',
#        'HN-CHUM-020', 'HN-CHUM-021', 'HN-CHUM-022', 'HN-CHUM-023',
#        'HN-CHUM-024', 'HN-CHUM-025', 'HN-CHUM-026', 'HN-CHUM-027',
#        'HN-CHUM-028', 'HN-CHUM-029', 'HN-CHUM-030', 'HN-CHUM-031',
#        'HN-CHUM-032', 'HN-CHUM-033', 'HN-CHUM-034', 'HN-CHUM-035',
#        'HN-CHUM-036', 'HN-CHUM-037', 'HN-CHUM-038', 'HN-CHUM-039',
#        'HN-CHUM-040', 'HN-CHUM-041', 'HN-CHUM-042', 'HN-CHUM-043',
#        'HN-CHUM-044', 'HN-CHUM-045', 'HN-CHUM-046', 'HN-CHUM-047',
#        'HN-CHUM-048', 'HN-CHUM-049', 'HN-CHUM-050', 'HN-CHUM-051',
#        'HN-CHUM-052', 'HN-CHUM-053', 'HN-CHUM-054', 'HN-CHUM-055',
#        'HN-CHUM-056', 'HN-CHUM-057', 'HN-CHUM-058', 'HN-CHUM-059',
#        'HN-CHUM-060', 'HN-CHUM-061', 'HN-CHUM-062', 'HN-CHUM-063',
#        'HN-CHUM-064', 'HN-CHUM-065'], dtype=object)
# array(['M', 'F', 'm'], dtype=object)
# array([79.        , 41.        , 75.        , 53.        , 74.        ,
#        62.        , 61.        , 59.        , 56.        , 60.        ,
#        51.        , 69.        , 52.        , 47.        , 65.        ,
#        64.        , 72.        , 45.        , 49.        , 18.        ,
#        73.        , 48.        , 76.        , 50.        , 54.        ,
#        57.        , 77.        , 81.        , 84.        , 80.        ,
#        58.        , 37.        , 66.        , 70.        , 67.        ,
#        63.        , 78.        , 71.        , 35.        , 68.        ,
#        34.        , 88.        , 82.        , 83.        , 85.        ,
#        44.        , 90.        , 77.21369863])
# array(['Larynx', 'Nasopharynx', 'Oropharynx', 'unknown', 'Hypopharynx'],
#       dtype=object)
# array(['T3', 'T1', 'T4', 'T2', 'Tx', 'T4b', 'T4a'], dtype=object)
# array(['N0', 'N1', 'N2b', 'N2c', 'N3', 'N2a', 'N2', 'N3b'], dtype=object)
# array(['M0', 'Mx'], dtype=object)
# array(['stage III', 'stage IIB', 'stage IVA', 'stage IV', 'stage IVB',
#        'stage II', 'stage I', 'Stade II', 'Stade III', 'Stade IVA',
#        'Stade I', 'Stade IVB', 'Stage III', 'Stage IVA', 'Stage IIB',
#        'Stage II', 'Stage IV', nan, 'StageII'], dtype=object)
# array(['-', nan, '+'], dtype=object)
# array([0])
# array([  71,   37,   49,   20,   41,   35,   22,   27,   21,   17,   36,
#           3,   61,   25,   33,   30,   76,   48,   26,   45,   32,   72,
#          69,   34,   12,   73,   63,   -5,   44,   47,   42,   40,   50,
#          29,  100,    7, -203,   28,   55,   62,   64,   23,  -10,   94,
#          43,   57,   14,   65,   39,   81,   53,   16,   24,   58,   31,
#          60,   70,   46,    2,    8,   38,  -20,   15,  -13,    9,   19,
#          -9,  101,   11,   -3,   51,   -1,   87,  -29,   -8, -202,   54,
#          80,   83,  108,   -6, -191,   13,  -19,   90,   91,    4])
# array([64, 35, 51, 16, 43, 29, 36, 38, 25, 20, 14, 30, -1, 56, 24, 26, 17,
#        69, 28, 65, 33, 40, 15, 68, 71, 66, 21, 31, -7, 37, 34, 41, 32, 27,
#        23, 39, 44, 99, 9, -210, 50, 57, 70, 59, -17, 93, 47, 13, 53, 63,
#        45, 62, 'TBD', 81, 72, 42, 22, 58, 60, 46, 49, 2, 8, -20, 48, 109,
#        100, 18, 78, -5, 52, -181, 106, 87], dtype=object)
# array([  97,   63,   65,   40,   71,   42,   48,   57,   41,   38,   49,
#          50,   13,   89,   45,   46,   37,   69,   39,   33,   55,   84,
#          90,   47,   88,   44,   77,   29,   56,   53,   58,   54,   59,
#         128,   24, -195,   76,   36,   85,   61,    3,  114,   52,   62,
#          34,   68,   78,   72,   51,   82,   96,   80,   98,   35,   74,
#          73,   81,   67,   60,   19,  118,   83,   21,   43,   70,   91,
#         102,  127,   87,   94, -161,  121,  111,   66,  104,   95,   75,
#         119, -179,   25,   31,    1,  103,   26,   30])
# array([ 140,  108,  113,   85,  120,   81,   87,  100,   83,   80,   98,
#          94,   63,  133,   92,   86,  134,  112,   82,   93,   90,  104,
#         128,  131,  103,  122,   70,  102,  105,   97,   99,   96,   88,
#         107,   91,  119,  178,   67,  101, -149,   89,  116,  117,   77,
#         126,   53,  158,  115,   95,  123,  106, -265,  121,  109,   62,
#         149,  124,  139,  129,   72,   79,  127,  118,   78,  150,  452,
#         110,   84,  458,   65,   66,  111,  136,  151,  175,  168,  141,
#          58, -116,  169,  156,  114,  132,  152,  164, -131,   74,   76,
#          46,  148,  147,   71,  130])
# array(['chemo radiation', 'radiation'], dtype=object)
# array([ 0.,  1., nan])
# array([2123., 2114., 1098., 2974., 2509., 3345.,  361., 2072., 1936.,
#        1938., 1887., 2002., 1414.,  479., 1133., 2498.,  859., 1451.,
#        1598., 2119.,  376., 1663., 3261.,  911., 2596., 2628., 2051.,
#        1634., 1846., 2133.,  884., 2972., 2940., 2684., 1962., 1495.,
#        1091.,  847., 2188.,  603., 2472., 2005., 3114., 1843., 1939.,
#        2010., 2449., 2751., 3402., 1697.,  887., 1923., 1966., 1374.,
#        2744.,  974., 2268., 2688., 1353., 1608.,  686., 1392., 1318.,
#        1376., 1280., 1262., 1384., 1311., 1003., 1014., 1030., 1298.,
#        1294., 1238., 1272., 1196., 1158., 1140., 1112.,  938., 1059.,
#         869.,  794.,  953.,  815.,  727.,  858.,  444.,  817.,  719.,
#         824.,   nan,  699.,  194.,  666., 2007., 1964., 1164., 1793.,
#         895., 2136., 2113.,  670.,  713., 1534., 1602., 2003., 1562.,
#         776., 1344., 2121., 1184.,  731., 1633., 1937., 1106.,  426.,
#         918.,  491., 1842., 1269., 1492.,  321.,  531., 1720.,  624.,
#        1850.,  585.,  255., 1468.,  668., 1806.,  805., 1841., 1776.,
#        1725., 1287., 1603., 1499., 1741., 1617., 1338., 1636., 1470.,
#        1511., 1233., 1449.,  350., 1343., 1357., 1412., 1147., 1268.,
#        1308.,  627., 1328., 1000., 1188., 1190., 1261., 1183., 1153.,
#        1237., 1207.,  891., 1076., 1132., 1120., 1222.,  966.,  753.,
#         862.,  980., 1310., 1427., 1465.,  787.,  766.,  818.,  943.,
#        1043.,  796.,  881.,  464., 1379., 2012.,  870.,  788.])
# array([1, 0])
# array([0, 1])
# array([0, 1])
# array([ 692.,  918.,  441.,   nan,  340., 1136., 1192.,  804., 1780.,
#        1729.,  348.,  418.,  726., 1771.,  281.,  809., 1191.,  407.,
#         783., 1053.,  525.,  495.,  197.,  580.,  143.,  410.,  490.,
#         135.,  249.,  266.,  523.,  436.,  609.,  216., 1554.,  307.,
#         621.,  631.,  222.,  571.,  186.,  279.,  993.,  531.,  428.,
#         832.])
# array([  nan,  441.,  332.,  164., 1228.,  181., 1149.,  741.,  408.,
#         280.,  649.,  805.,  211.,  699.,  329.,  328.,  949., 1504.,
#         899.,  464.,  496.,  360.,  447.,  345.,  457.,  138., 1071.,
#         618.,  725.,  596.,  202.,  434., 1554.,  307.,  289.,  222.,
#        1233.,  624.,  832.])
# array([  nan, 1098., 2509.,  361.,  551.,  859., 1598.,  414.,  911.,
#        1634.,  603., 1843.,  887.,  974.,  686., 2474.,  607., 1982.,
#         907., 1672., 2183., 1519., 1137.,  970., 1452., 1332., 1148.,
#         245., 1083.,  528.,  396.,  518.,  580., 1521.,  195.,  864.,
#        2044., 1094.,  749., 1395.,  783.,  437.,  968.,  540., 1563.,
#         323.,  531.,  730.,  639.,  740.,  288.,  350.,  627., 1076.,
#         766.,  464.])
# array(['Jewish General', 'Univ of Sherbrooke', 'Maisonneuve-Rosemont',
#        'Montreal Univ'], dtype=object)
# array([  nan, 2442., 2841., 2474.,  793., 2165.,  880.,  607., 2378.,
#        2616., 1658., 2571.,  504., 1982., 1597., 1975., 2506., 1707.,
#        2393., 1739., 2218., 1277.,  907., 1672., 2183., 1519., 1943.,
#        1174., 1504., 2001., 1137., 2107., 1952., 1315., 1949.,  970.,
#        1824., 1452., 1936., 1332., 1651., 1836., 1728., 1735., 1760.,
#        1548., 1696., 1618., 1546., 1148., 1556.,  495., 1588.,  245.,
#         650., 1083.,  948., 1540., 1533.,  528., 1527., 1436., 1521.,
#        1478., 1487., 1429., 1430., 1340., 1387., 1330.,  834., 1182.,
#         451., 1401., 1158., 1324.,  396.,  518., 1201., 1211., 1270.,
#        1019., 1120., 1030., 1099., 1126.,  991., 1077., 1023.,  898.,
#        1001.,  781.,  993.,  904.,  934.,  815.,  580.,  462.,  499.,
#         468.])

# %%
data_raw['Sex'] = data_raw['Sex'].replace({'m': 'M'})
data_raw['Age'] = data_raw['Age'].replace({77.213699: 77})
data_raw['TNM group stage'] = data_raw['TNM group stage'].replace({'stage III':'III',
                                                                   'stage IIB':'IIB',
                                                                   'stage IVA':'IVA',
                                                                   'stage IV':'IV',
                                                                   'stage IVB':'IVB',
                                                                   'stage II':'II',
                                                                   'stage I':'I',
                                                                   'Stade II':'II',
                                                                   'Stade III':'III',
                                                                   'Stade IVA':'IVA',
                                                                   'Stade I':'I',
                                                                   'Stade IVB':'IVB',
                                                                   'Stage III':'III',
                                                                   'Stage IVA':'IVA',
                                                                   'Stage IIB':'IIB',
                                                                   'Stage II':'II',
                                                                   'Stage IV':'IV',
                                                                   'StageII':'II'})

# %%
data_raw.dtypes
# Out:
# Patient #                                      object
# Sex                                            object
# Age                                           float64
# Primary Site                                   object
# T-stage                                        object
# N-stage                                        object
# M-stage                                        object
# TNM group stage                                object
# HPV status                                     object
# Time – diagnosis to diagnosis (days)            int64
# Time – diagnosis to PET (days)                  int64
# Time – diagnosis to CT sim (days)              object
# Time – diagnosis to start treatment (days)      int64
# Time – diagnosis to end treatment (days)        int64
# Therapy                                        object
# Surgery                                       float64
# Time – diagnosis to last follow-up(days)      float64
# Locoregional                                    int64
# Distant                                         int64
# Death                                           int64
# Time – diagnosis to LR (days)                 float64
# Time – diagnosis to DM (days)                 float64
# Time – diagnosis to Death (days)              float64
# Hospital                                       object
# Time – diagnosis to last follow-up (days)     float64
# dtype: object

# %%
#this chart shows on the x axis, the age of the patient at entry into the study, and on the y axis the number of days
#to LR DM, or Death
df = data_raw[['Age', 'Time – diagnosis to LR (days)', 'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)', 'Locoregional', 'Distant', 'Death', 'Therapy', 'Surgery']]
df['event'] = df[['Time – diagnosis to LR (days)','Time – diagnosis to DM (days)','Time – diagnosis to Death (days)']].min(axis=1)
df = df[df['event'].notna()]

def set_color(df):
    if df['Locoregional'] == 1:
        return 'Locoregional Metastasis'
    elif df['Distant'] == 1:
        return 'Distant Metastasis'
    else:
        return "Death"

df = df.assign(color=df.apply(set_color, axis=1))


#color="species", symbol="species"
fig = px.scatter(df, x="Age", y="event", height=1000, width=800, symbol="Death", color='color', facet_row='Therapy', labels={"Age": "Age (years)",
                                                                                                                             "event": "Time to Event (days)"},)
fig.show()

plt.savefig("scatter.png", dpi=100)
# Out:
# <ipython-input-411-b7753d6bde15>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#            Age  Time – diagnosis to LR (days)  Time – diagnosis to DM (days)  \
# 0    79.000000                          692.0                            NaN
# 1    41.000000                          918.0                            NaN
# 2    75.000000                          441.0                          441.0
# 4    74.000000                            NaN                            NaN
# 6    62.000000                            NaN                          332.0
# ..         ...                            ...                            ...
# 271  61.000000                            NaN                          624.0
# 283  71.000000                          993.0                            NaN
# 285  62.000000                          531.0                            NaN
# 293  72.000000                          428.0                            NaN
# 295  77.213699                          832.0                          832.0
#
#      Time – diagnosis to Death (days)  Locoregional  Distant  Death  \
# 0                                 NaN             1        0      0
# 1                                 NaN             1        0      0
# 2                              1098.0             1        1      1
# 4                              2509.0             0        0      1
# 6                               361.0             0        1      1
# ..                                ...           ...      ...    ...
# 271                            1076.0             0        1      1
# 283                               NaN             1        0      0
# 285                             766.0             1        0      1
# 293                             464.0             1        0      1
# 295                               NaN             1        1      0
#
#              Therapy  Surgery   event                    color
# 0    chemo radiation      0.0   692.0  Locoregional Metastasis
# 1    chemo radiation      0.0   918.0  Locoregional Metastasis
# 2    chemo radiation      0.0   441.0  Locoregional Metastasis
# 4    chemo radiation      0.0  2509.0                    Death
# 6    chemo radiation      0.0   332.0       Distant Metastasis
# ..               ...      ...     ...                      ...
# 271  chemo radiation      NaN   624.0       Distant Metastasis
# 283  chemo radiation      NaN   993.0  Locoregional Metastasis
# 285  chemo radiation      NaN   531.0  Locoregional Metastasis
# 293  chemo radiation      NaN   428.0  Locoregional Metastasis
# 295  chemo radiation      NaN   832.0  Locoregional Metastasis
#
# [90 rows x 11 columns]

# %%
sns.set(rc = {'figure.figsize':(12,6)})
sns.set_style("white")

df_new = data_raw.groupby(['Primary Site', 'TNM group stage']).size().reset_index(name='count') #wrangle count data
df_new = df_new.pivot("Primary Site", "TNM group stage", "count")

df_new
# Out:
# TNM group stage    I    II  IIB   III    IV    IVA  IVB
# Primary Site
# Hypopharynx      NaN   2.0  NaN   3.0   1.0    4.0  3.0
# Larynx           2.0   5.0  NaN  19.0   NaN   18.0  1.0
# Nasopharynx      NaN   2.0  3.0  12.0   1.0    6.0  4.0
# Oropharynx       2.0  15.0  NaN  27.0  49.0  101.0  9.0
# unknown          NaN   NaN  NaN   NaN   6.0    1.0  NaN

# %%
ax = sns.heatmap(df_new, annot=True, fmt='.0f', cmap="YlGnBu", linewidths=1.0, mask=(df_new==0))
plt.ylim(reversed(plt.ylim()))
ax.set_xlabel("TNM Group Stage", labelpad=15, size=13)
ax.set_ylabel("Primary Tumour Site", labelpad=15, size=13)
ax.set_title("Tumour Site vs. TNM Group Stage (n=90)", size=15, pad=15)
# Out:
# Text(0.5, 1.0, 'Tumour Site vs. TNM Group Stage (n=90)')

# %%
fig = px.pie(data_raw, names='Primary Site', title='Anatomic Location of Cancerous Lesion (n=298)', hover_data=['Primary Site'], labels={'Site':'Primary Site'}, width=700, height=700, color_discrete_sequence=px.colors.sequential.RdBu_r)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
fig = px.pie(data_raw, names='T-stage', title='T-stage (n=298)', hover_data=['T-stage'], labels={'T-stage':'T-stage'},  width=700, height=700, color_discrete_sequence=px.colors.sequential.RdBu_r)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
fig = px.pie(data_raw, names='N-stage', title='N-Stage (n=298)', hover_data=['N-stage'], labels={'N-stage':'N-stage'}, width=700, height=700, color_discrete_sequence=px.colors.sequential.RdBu_r)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
fig = px.pie(data_raw, names='TNM group stage', title='TNM group stage (n=298)', hover_data=['TNM group stage'], labels={'TNM group stage':'M-stage'}, width=700, height=700, color_discrete_sequence=px.colors.sequential.RdBu_r)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
fig = px.pie(data_raw, names='HPV status', title='HPV status (n=298)', hover_data=['HPV status'], labels={'HPV status':'HPV status'}, width=700, height=700, color_discrete_sequence=px.colors.sequential.RdBu_r)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
fig = px.pie(data_raw, names='Hospital', title='Hospital (n=298)', hover_data=['Hospital'], labels={'Hospital':'Hospital'}, width=700, height=700, color_discrete_sequence=px.colors.sequential.RdBu_r)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
fig = px.histogram(data_raw, x="Age", color="Sex", title='Histogram of Age (Segregated by Sex) (n=298)', width=700, height=700, color_discrete_sequence=px.colors.sequential.RdBu_r)
fig.show()

# %% [markdown]
# # Data for RStudio

# %%
data_raw.columns
# Out:
# Index(['Patient #', 'Sex', 'Age', 'Primary Site', 'T-stage', 'N-stage',
#        'M-stage', 'TNM group stage', 'HPV status',
#        'Time – diagnosis to diagnosis (days)',
#        'Time – diagnosis to PET (days)', 'Time – diagnosis to CT sim (days)',
#        'Time – diagnosis to start treatment (days)',
#        'Time – diagnosis to end treatment (days)', 'Therapy', 'Surgery',
#        'Time – diagnosis to last follow-up(days)', 'Locoregional', 'Distant',
#        'Death', 'Time – diagnosis to LR (days)',
#        'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)',
#        'Hospital', 'Time – diagnosis to last follow-up (days)'],
#       dtype='object')

# %%
data_raw.groupby(['Primary Site']).size()
# Out:
# Primary Site
# Hypopharynx     13
# Larynx          45
# Nasopharynx     28
# Oropharynx     203
# unknown          9
# dtype: int64

# %%
#data_raw['Time – diagnosis to Death (days)'].max()

# %%
SA_df = data_raw[['Patient #', 'Sex', 'Primary Site', 'T-stage', 'N-stage', 'M-stage',
                  'TNM group stage', 'HPV status', 'Time – diagnosis to last follow-up(days)',
                  'Therapy', 'Locoregional', 'Distant', 'Death', 'Time – diagnosis to LR (days)',
                  'Time – diagnosis to DM (days)', 'Time – diagnosis to Death (days)']]

#remove those with null for TNM group stage
SA_df = SA_df[SA_df['TNM group stage'].notna()]

#remove those for unknown primary site
SA_df = SA_df[(SA_df['Primary Site'] != 'unknown')]

#if event didn't occur, fill with time to last follow-up
SA_df['Time – diagnosis to LR (days)'] = SA_df['Time – diagnosis to LR (days)'].fillna(SA_df['Time – diagnosis to last follow-up(days)'])
SA_df['Time – diagnosis to DM (days)'] = SA_df['Time – diagnosis to DM (days)'].fillna(SA_df['Time – diagnosis to last follow-up(days)'])
SA_df['Time – diagnosis to Death (days)'] = SA_df['Time – diagnosis to Death (days)'].fillna(SA_df['Time – diagnosis to last follow-up(days)'])

SA_df = SA_df.rename(columns={"Time – diagnosis to LR (days)": "LR_Time",
                              "Time – diagnosis to DM (days)": "DM_Time",
                              "Time – diagnosis to Death (days)": "Death_Time"})

def set_cstage(SA_df):
    if SA_df['TNM group stage'] == 'I':
        return 'Early Stage'
    elif SA_df['TNM group stage'] == 'II':
        return 'Early Stage'
    elif SA_df['TNM group stage'] == 'IIB':
        return 'Early Stage'
    else:
        return "Late Stage"

SA_stage_df = SA_df.assign(early_late=SA_df.apply(set_cstage, axis=1))

SA_stage_df = SA_stage_df.rename(columns={"Time – diagnosis to LR (days)": "LR_Time",
                                          "Time – diagnosis to DM (days)": "DM_Time",
                                          "Time – diagnosis to Death (days)": "Death_Time"})

SA_stage_df = SA_stage_df[SA_stage_df['LR_Time'].notna()]
SA_stage_df = SA_stage_df[SA_stage_df['DM_Time'].notna()]
SA_stage_df = SA_stage_df[SA_stage_df['Death_Time'].notna()]

SA_stage_df
# Out:
#        Patient # Sex Primary Site T-stage N-stage M-stage TNM group stage  \
# 0     HN-HGJ-001   M       Larynx      T3      N0      M0             III
# 1     HN-HGJ-002   M  Nasopharynx      T1      N1      M0             IIB
# 2     HN-HGJ-003   M       Larynx      T3     N2b      M0             IVA
# 3     HN-HGJ-004   M  Nasopharynx      T3      N1      M0             III
# 4     HN-HGJ-005   M  Nasopharynx      T1      N1      M0             IIB
# ..           ...  ..          ...     ...     ...     ...             ...
# 293  HN-CHUM-061   M   Oropharynx      T2      N2      M0              IV
# 294  HN-CHUM-062   M   Oropharynx      T3      N1      M0             III
# 295  HN-CHUM-063   M   Oropharynx      T3      N2      M0              IV
# 296  HN-CHUM-064   M   Oropharynx      T3      N3      M0              IV
# 297  HN-CHUM-065   M   Oropharynx      T3      N0      M0              IV
#
#     HPV status  Time – diagnosis to last follow-up(days)          Therapy  \
# 0            -                                    2123.0  chemo radiation
# 1            -                                    2114.0  chemo radiation
# 2          NaN                                    1098.0  chemo radiation
# 3          NaN                                    2974.0        radiation
# 4            -                                    2509.0  chemo radiation
# ..         ...                                       ...              ...
# 293        NaN                                     464.0  chemo radiation
# 294        NaN                                    1379.0  chemo radiation
# 295        NaN                                    2012.0  chemo radiation
# 296        NaN                                     870.0  chemo radiation
# 297        NaN                                     788.0  chemo radiation
#
#      Locoregional  Distant  Death  LR_Time  DM_Time  Death_Time   early_late
# 0               1        0      0    692.0   2123.0      2123.0   Late Stage
# 1               1        0      0    918.0   2114.0      2114.0  Early Stage
# 2               1        1      1    441.0    441.0      1098.0   Late Stage
# 3               0        0      0   2974.0   2974.0      2974.0   Late Stage
# 4               0        0      1   2509.0   2509.0      2509.0  Early Stage
# ..            ...      ...    ...      ...      ...         ...          ...
# 293             1        0      1    428.0    464.0       464.0   Late Stage
# 294             0        0      0   1379.0   1379.0      1379.0   Late Stage
# 295             1        1      0    832.0    832.0      2012.0   Late Stage
# 296             0        0      0    870.0    870.0       870.0   Late Stage
# 297             0        0      0    788.0    788.0       788.0   Late Stage
#
# [190 rows x 17 columns]

# %%
#remove those with null for HPV status
HPV_df = SA_df[SA_df['HPV status'].notna()]

HPV_df = HPV_df[HPV_df['LR_Time'].notna()]
HPV_df = HPV_df[HPV_df['DM_Time'].notna()]
HPV_df = HPV_df[HPV_df['Death_Time'].notna()]

HPV_df
# Out:
#        Patient # Sex Primary Site T-stage N-stage M-stage TNM group stage  \
# 0     HN-HGJ-001   M       Larynx      T3      N0      M0             III
# 1     HN-HGJ-002   M  Nasopharynx      T1      N1      M0             IIB
# 4     HN-HGJ-005   M  Nasopharynx      T1      N1      M0             IIB
# 6     HN-HGJ-007   M   Oropharynx      T4     N2b      M0             IVA
# 8     HN-HGJ-009   M       Larynx      T3      N0      M0             III
# ..           ...  ..          ...     ...     ...     ...             ...
# 283  HN-CHUM-051   M   Oropharynx      T2      N2      M0              IV
# 285  HN-CHUM-053   F   Oropharynx      T3      N2      M0              IV
# 287  HN-CHUM-055   F   Oropharynx      T4      N1      M0              IV
# 290  HN-CHUM-058   F   Oropharynx      T2      N3      M0              IV
# 292  HN-CHUM-060   M   Oropharynx      T4      N3      M0              IV
#
#     HPV status  Time – diagnosis to last follow-up(days)          Therapy  \
# 0            -                                    2123.0  chemo radiation
# 1            -                                    2114.0  chemo radiation
# 4            -                                    2509.0  chemo radiation
# 6            +                                     361.0  chemo radiation
# 8            -                                    1936.0  chemo radiation
# ..         ...                                       ...              ...
# 283          +                                    1465.0  chemo radiation
# 285          -                                     766.0  chemo radiation
# 287          +                                    1238.0  chemo radiation
# 290          +                                     974.0  chemo radiation
# 292          +                                     881.0  chemo radiation
#
#      Locoregional  Distant  Death  LR_Time  DM_Time  Death_Time
# 0               1        0      0    692.0   2123.0      2123.0
# 1               1        0      0    918.0   2114.0      2114.0
# 4               0        0      1   2509.0   2509.0      2509.0
# 6               0        1      1    361.0    332.0       361.0
# 8               0        0      0   1936.0   1936.0      1936.0
# ..            ...      ...    ...      ...      ...         ...
# 283             1        0      0    993.0   1465.0      1465.0
# 285             1        0      1    531.0    766.0       766.0
# 287             0        0      0   1238.0   1238.0      1238.0
# 290             0        0      0    974.0    974.0       974.0
# 292             0        0      0    881.0    881.0       881.0
#
# [83 rows x 16 columns]

# %%
def set_anat(SA_df):
    if SA_df['Primary Site'] == 'Oropharynx':
        return 'Oropharynx'
    else:
        return "Non-Oropharnyx"

SA_anat_df = SA_df.assign(anatomy=SA_df.apply(set_anat, axis=1))

SA_anat_df = SA_anat_df[SA_anat_df['LR_Time'].notna()]
SA_anat_df = SA_anat_df[SA_anat_df['DM_Time'].notna()]
SA_anat_df = SA_anat_df[SA_anat_df['Death_Time'].notna()]

SA_anat_df
# Out:
#        Patient # Sex Primary Site T-stage N-stage M-stage TNM group stage  \
# 0     HN-HGJ-001   M       Larynx      T3      N0      M0             III
# 1     HN-HGJ-002   M  Nasopharynx      T1      N1      M0             IIB
# 2     HN-HGJ-003   M       Larynx      T3     N2b      M0             IVA
# 3     HN-HGJ-004   M  Nasopharynx      T3      N1      M0             III
# 4     HN-HGJ-005   M  Nasopharynx      T1      N1      M0             IIB
# ..           ...  ..          ...     ...     ...     ...             ...
# 293  HN-CHUM-061   M   Oropharynx      T2      N2      M0              IV
# 294  HN-CHUM-062   M   Oropharynx      T3      N1      M0             III
# 295  HN-CHUM-063   M   Oropharynx      T3      N2      M0              IV
# 296  HN-CHUM-064   M   Oropharynx      T3      N3      M0              IV
# 297  HN-CHUM-065   M   Oropharynx      T3      N0      M0              IV
#
#     HPV status  Time – diagnosis to last follow-up(days)          Therapy  \
# 0            -                                    2123.0  chemo radiation
# 1            -                                    2114.0  chemo radiation
# 2          NaN                                    1098.0  chemo radiation
# 3          NaN                                    2974.0        radiation
# 4            -                                    2509.0  chemo radiation
# ..         ...                                       ...              ...
# 293        NaN                                     464.0  chemo radiation
# 294        NaN                                    1379.0  chemo radiation
# 295        NaN                                    2012.0  chemo radiation
# 296        NaN                                     870.0  chemo radiation
# 297        NaN                                     788.0  chemo radiation
#
#      Locoregional  Distant  Death  LR_Time  DM_Time  Death_Time  \
# 0               1        0      0    692.0   2123.0      2123.0
# 1               1        0      0    918.0   2114.0      2114.0
# 2               1        1      1    441.0    441.0      1098.0
# 3               0        0      0   2974.0   2974.0      2974.0
# 4               0        0      1   2509.0   2509.0      2509.0
# ..            ...      ...    ...      ...      ...         ...
# 293             1        0      1    428.0    464.0       464.0
# 294             0        0      0   1379.0   1379.0      1379.0
# 295             1        1      0    832.0    832.0      2012.0
# 296             0        0      0    870.0    870.0       870.0
# 297             0        0      0    788.0    788.0       788.0
#
#             anatomy
# 0    Non-Oropharnyx
# 1    Non-Oropharnyx
# 2    Non-Oropharnyx
# 3    Non-Oropharnyx
# 4    Non-Oropharnyx
# ..              ...
# 293      Oropharynx
# 294      Oropharynx
# 295      Oropharynx
# 296      Oropharynx
# 297      Oropharynx
#
# [190 rows x 17 columns]

# %%
#SA_df.groupby(['Primary Site']).size()
#HPV_df = SA_df.groupby(['HPV status']).size()

#early vs late
#oropharynx vs anatomically lower
#HPV status + vs HPV status -

# %%
#general SA stage dataframe output to csv
SA_stage_df.to_csv('SA_df.csv', encoding='utf-8', index=False)

# %%
#general SA anatomy dataframe output to csv
SA_anat_df.to_csv('SA_anat_df.csv', encoding='utf-8', index=False)

# %%
#filtered HPV SA dataframe output to csv
HPV_df.to_csv('HPV_SA_df.csv', encoding='utf-8', index=False)
